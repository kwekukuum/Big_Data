# %% [markdown]
# <a href="https://colab.research.google.com/github/kwekukuum/Big_Data/blob/main/Group_7_API_Stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Streaming Api from Yahoo Finance

# %%
# import requests

# url = "https://xsportbox-livestreams.p.rapidapi.com/events"

# headers = {
#     "Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJhdWQiOiIxIiwianRpIjoiMzU1OTA5NjkxOTc1YzgxOGZiMjVhOTRmNzNkMjBkY2U5OGU4NDE0YzFhZTRkOWM4Yjk3M2VmMjhmZDljYjk0ZTRlYzFkMmE2MjViYWY0Y2QiLCJpYXQiOjE1ODE2NzE4MjUsIm5iZiI6MTU4MTY3MTgyNSwiZXhwIjoxNjEzMjk0MjI1LCJzdWIiOiIyIiwic2NvcGVzIjpbXX0.JIuvL4HNYBxlzzjHYQr7-2FFn4gBYwoAopaSBEZzPY3xHYHx6TgnxifqGeAbKamwJRQMrTXwKrNqGgybMmodf7qoZig9tuiVaHbwca-E7wld5nblUfZCCL-GbZXb2yGdvfYPK-F_9rnQW8T8FqKl-INEihykf1qlUeQzk1KdEyU5Sal3d8Q3wyxiHWnOvifJcola4UtfHHi28WWhUaNBbigmmAa1bMasT4ue4hk4xR6wNJotGJS9Py5Y7VlUL1um32X57Dnv6TWasWSfOEeBwmvaWpEri21lG7RMNXQMB_qV0lpg9umG7nN-IG44D9MFU6yL9SNQhw6vR8EDrg9IxBBo93Y7rRmVfuu2p_1QjNCA5p115eDp2KXxhNwUFOR3Ys5D0BKw9XT2szhKsH19SK7AOIfJkMXpgvsRuoaV6Bp9R4G88wHVicKvQBAc2utA9qPkMf1VussOcHn99CbLNpdnY7n7h39aFSx2VyzVGNHrWjcD2BX69_QI05UQaSxqG-fExfjZQ5FcDOvcvENvh-nBq2GdGADf9uF_BbRKOsgQkHRFR0KuVYC5IPAKAEjLwz40jXtoP27PslO5V1-WBTCdbXgu6R2ocgYrUbAh04g0TX_OXHXcmUBhLmTHqNs75rfFDWVXfCp_5H0P46nNnetB9fHcArQUTjGv64Mu2QI",
#     "X-RapidAPI-Key": "28c98db3femshbb4d3858466dfc9p181568jsn0e606049b344",
#     "X-RapidAPI-Host": "xsportbox-livestreams.p.rapidapi.com",
# }

# params = {"cat": "football"}

# response = requests.get(url, headers=headers, params=params)

# if response.status_code == 200:
#     print(response.json())
# else:
#     print(f"Request failed with status code {response.status_code}")
# Out:
# Request failed with status code 502

# %%
# import requests

# url = 'https://dark-sky.p.rapidapi.com/{latitude},{longitude}'
# headers = {
#     'X-RapidAPI-Key': '28c98db3femshbb4d3858466dfc9p181568jsn0e606049b344',
#     'X-RapidAPI-Host': 'dark-sky.p.rapidapi.com'
# }
# params = {
#     'units': 'auto',
#     'lang': 'en'
# }
# latitude = '45.9636'
# longitude = '66.6431°'

# response = requests.get(url.format(latitude=latitude, longitude=longitude), headers=headers, params=params)

# if response.status_code == 200:
#     print(response.json())
# else:
#     print(f"Request failed with status code {response.status_code}")
# Out:
# Request failed with status code 403

# %%
import requests
import json

url = "https://yh-finance.p.rapidapi.com/auto-complete"

querystring = {"q":"facebook","region":"US"}

headers = {
    "X-RapidAPI-Key": "28c98db3femshbb4d3858466dfc9p181568jsn0e606049b344",
    "X-RapidAPI-Host": "yh-finance.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# print(response.json())
response_format = response.json()
formated_response = json.dumps(response_format, indent= 4)
print(formated_response)
# Out:
# {
#     "explains": [],
#     "count": 15,
#     "quotes": [
#         {
#             "exchange": "NMS",
#             "shortname": "Meta Platforms, Inc.",
#             "quoteType": "EQUITY",
#             "symbol": "META",
#             "index": "quotes",
#             "score": 247775.0,
#             "typeDisp": "Equity",
#             "longname": "Meta Platforms, Inc.",
#             "exchDisp": "NASDAQ",
#             "sector": "Communication Services",
#             "industry": "Internet Content & Information",
#             "dispSecIndFlag": true,
#             "isYahooFinance": true,
#             "prevName": "Facebook, Inc.",
#             "nameChangeDate": "2023-02-22"
#         },
#         {
#             "exchange": "LSE",
#             "shortname": "LEVERAGE SHARES PUBLIC LIMITED ",
#             "quoteType": "EQUITY",
#             "symbol": "FB3.L",
#             "index": "quotes",
#             "score": 20107.0,
#             "typeDisp": "Equity",
# ...
